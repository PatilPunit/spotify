# %%
#reading csv files
import pandas as pd
df=pd.read_csv('/home/punit/Documents/soptify/datase/dataset.csv')

# %%
#identifying null values
df.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#operating null values
df['artists']=df['artists'].ffill()
df['album_name']=df['album_name'].ffill()
df['track_name']=df['track_name'].ffill()
df.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df.to_csv('/home/punit/Documents/soptify/Data_clean/clean_data.csv',index=False)
