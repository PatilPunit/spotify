# %%
import pandas as pd
df=pd.read_csv('/home/punit/Downloads/Mint/soptify/datase/clean_data.csv')
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# 2                   To Begin Again          57       210826     False
# 3       Can't Help Falling In Love          71       201933     False
# 4                          Hold On          82       198853     False
# ...                            ...         ...          ...       ...
# 113995         Sleep My Little Boy          21       384999     False
# 113996            Water Into Light          22       385000     False
# 113997              Miss Perfumado          22       271466     False
# 113998                     Friends          41       283893     False
# 113999                   Barbincor          22       241826     False
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430  ...    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350  ...   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170  ...   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290  ...   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060  ...   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870  ...   -10.204     0       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001    0.3580   0.7150   87.917               4
# 1               0.000006    0.1010   0.2670   77.489               4
# 2               0.000000    0.1170   0.1200   76.332               4
# 3               0.000071    0.1320   0.1430  181.740               3
# 4               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113995          0.928000    0.0863   0.0339  125.995               5
# 113996          0.976000    0.1050   0.0350   85.239               4
# 113997          0.000000    0.0839   0.7430  132.378               4
# 113998          0.000000    0.2700   0.4130  135.960               4
# 113999          0.000000    0.0893   0.7080   79.198               4
#
#         track_genre
# 0          acoustic
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
# ...             ...
# 113995  world-music
# 113996  world-music
# 113997  world-music
# 113998  world-music
# 113999  world-music
#
# [114000 rows x 21 columns]

# %%
import seaborn as sea
import matplotlib.pyplot as plt

sea.set_theme('notebook')
sea.set_style('whitegrid'
plt.figure(figsize=(14,10))
sea.histplot(data=df['popularity'],bins=20,kde=True)
# Out:
# <Axes: xlabel='popularity', ylabel='Count'>

# %%
import seaborn as sea
import matplotlib.pyplot as plt
df_pop=df[['popularity','duration_ms']]
plt.figure(figsize=(14,10))
sea.kdeplot(data=df_pop,x='popularity')
plt.show()

# %%
df_pop=df[['popularity','duration_ms']]
plt.figure(figsize=(14,10))
sea.barplot(data=df_pop,x='popularity',y='duration_ms')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,10))
df_pop=df[['popularity','danceability']]
sea.lineplot(data=df_pop,x='popularity',y='danceability')
plt.xticks(rotation=90)
plt.show()

# %%
df['track_genre'].value_counts()
# Out:
# track_genre
# acoustic       1000
# afrobeat       1000
# alt-rock       1000
# alternative    1000
# ambient        1000
#                ...
# techno         1000
# trance         1000
# trip-hop       1000
# turkish        1000
# world-music    1000
# Name: count, Length: 114, dtype: int64

# %%
pop_80=df[df['popularity']>80]

genre=pop_80['track_genre'].value_counts()
plt.figure(figsize=(14,10))
sea.barplot(y=genre.index,x=genre.values)
plt.show()

# %%
dance_80=df[df['danceability']>0.80]
dance_80
# Out:
#         Unnamed: 0                track_id                            artists  \
# 448            448  6339iq4yAm87arKgnNc922                            Zee Avi
# 616            616  7pxbZ29k1LJXvOdd2e5Bdn                         Us The Duo
# 656            656  3zjr7jirhGwvqGuuJuIxjg               Andrew Foy;Renee Foy
# 663            663  12qmPGMrOCogibc7qyxT9s                        Gen Hoshino
# 713            713  1z2fSrYZqrO5tMqzULn9OD                       Tyrone Wells
# ...            ...                     ...                                ...
# 112869      112869  3kVFYB1LkUYH4Q8cjpIJq6                      Sagopa Kajmer
# 112909      112909  3jxn92KU8l5RPjwLTGlMyg  Arem Ozguc;Arman Aydin;Jordan Rys
# 112913      112913  59YZrBAIg1tDH8squLd7gY                         Cem Adrian
# 113696      113696  797ikuM3k4gkjaxStQnxgW            Cesária Evora;Ismaël Lô
# 113942      113942  1QwLpfmZ6NPzjk3YFXkl0E                      Cesária Evora
#
#                                   album_name  \
# 448              Acoustic Christmas Campfire
# 616                                  Shotgun
# 656                               Photograph
# 663     I Wanna Be Your Ghost (feat. Ghosts)
# 713                    The "Hits" | Acoustic
# ...                                      ...
# 112869                            Romantizma
# 112909                               The One
# 112913                             Salvatore
# 113696                               Rogamar
# 113942                           Voz D' Amor
#
#                                   track_name  popularity  duration_ms  \
# 448                      No Christmas For Me           0       160666
# 616                                  Shotgun          45       174884
# 656                               Photograph          30       218590
# 663     I Wanna Be Your Ghost (feat. Ghosts)          50       225533
# 713                     Days I Will Remember          30       201506
# ...                                      ...         ...          ...
# 112869                                 Leyli          37       197696
# 112909                               The One          56       133375
# 112913                             Salvatore          37       197513
# 113696         Africa Nossa (with Ismaël Lô)          25       232146
# 113942                         Beijo Roubado          22       249733
#
#         explicit  danceability  energy  ...  loudness  mode  speechiness  \
# 448        False         0.809  0.3130  ...   -12.182     1       0.0428
# 616        False         0.806  0.2630  ...   -10.430     1       0.0502
# 656        False         0.807  0.0459  ...   -19.883     1       0.0481
# 663        False         0.829  0.7510  ...    -4.937     0       0.0645
# 713        False         0.804  0.4570  ...    -7.845     1       0.1970
# ...          ...           ...     ...  ...       ...   ...          ...
# 112869     False         0.856  0.5960  ...    -6.388     0       0.2070
# 112909     False         0.863  0.6240  ...    -6.574     0       0.0437
# 112913     False         0.811  0.5210  ...    -6.038     0       0.0374
# 113696     False         0.804  0.8540  ...    -7.937     1       0.0487
# 113942     False         0.838  0.4710  ...    -9.141     0       0.0335
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 448         0.876000          0.000000    0.1120    0.350  114.955
# 616         0.787000          0.000000    0.1820    0.868  115.854
# 656         0.852000          0.000006    0.1020    0.275  110.512
# 663         0.014200          0.014000    0.0414    0.960  129.993
# 713         0.600000          0.000000    0.1500    0.552   98.035
# ...              ...               ...       ...      ...      ...
# 112869      0.391000          0.000006    0.1040    0.578   94.973
# 112909      0.000316          0.000131    0.0822    0.482  120.020
# 112913      0.246000          0.000010    0.1400    0.714  114.877
# 113696      0.611000          0.000083    0.3950    0.841  104.004
# 113942      0.798000          0.000024    0.2390    0.855  103.008
#
#         time_signature  track_genre
# 448                  4     acoustic
# 616                  4     acoustic
# 656                  4     acoustic
# 663                  4     acoustic
# 713                  4     acoustic
# ...                ...          ...
# 112869               4      turkish
# 112909               4      turkish
# 112913               4      turkish
# 113696               4  world-music
# 113942               4  world-music
#
# [8768 rows x 21 columns]

# %%
plt.figure(figsize=(14,10))
sea.barplot(data=df,x='popularity',y='danceability')
plt.xticks(rotation=90)
plt.show()
